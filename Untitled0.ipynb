# %% [markdown]
# <a href="https://colab.research.google.com/github/CCMStorm/CIS115-Spring2026-Assignments/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This is my first Python comment.

# %%
# This is my second Python comment.
